# %%
import pandas as pd

# %%
df = pd.concat(
    map(pd.read_csv, ['csv_files/articles1.csv', 'csv_files/articles01.csv','csv_files/articles2.csv',
                     'csv_files/articles02.csv','csv_files/articles3.csv' ,'csv_files/articles4.csv',
                     'csv_files/articles5.csv','csv_files/articles6.csv','csv_files/articles7.csv']), ignore_index=True)

df
# Out:
#                                                   source  \
# 0                   {'id': None, 'name': 'Stanford.edu'}
# 1             {'id': None, 'name': 'Marketscreener.com'}
# 2                           {'id': None, 'name': 'CNET'}
# 3      {'id': None, 'name': 'Phandroid - News for And...
# 4                           {'id': None, 'name': 'CNET'}
# ...                                                  ...
# 25368                        {'id': None, 'name': 'NPR'}
# 25369         {'id': None, 'name': 'Marketscreener.com'}
# 25370         {'id': None, 'name': 'Marketscreener.com'}
# 25371         {'id': None, 'name': 'Marketscreener.com'}
# 25372         {'id': None, 'name': 'Marketscreener.com'}
#
#                      author                                     title  \
# 0      Alex Samuel Harvison  Devices and electromechanical Structures
# 1            MarketScreener  Devices and electromechanical Structures
# ...

# %%
df.shape
# Out:
# (25373, 8)

# %%
df.drop_duplicates(subset=['description'], inplace=True)

# %%
df.shape
# Out:
# (16249, 8)

# %%
df.to_csv('source/articles.csv', index=False)
